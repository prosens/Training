# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/prosenjitsinha/Projects/advertising.csv')
df.head(20)
# Out:
#     Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                      68.95   35     61833.90                256.09
# 1                      80.23   31     68441.85                193.77
# 2                      69.47   26     59785.94                236.50
# 3                      74.15   29     54806.18                245.89
# 4                      68.37   35     73889.99                225.58
# 5                      59.99   23     59761.56                226.74
# 6                      88.91   33     53852.85                208.36
# 7                      66.00   48     24593.33                131.76
# 8                      74.53   30     68862.00                221.51
# 9                      69.88   20     55642.32                183.82
# 10                     47.64   49     45632.51                122.02
# 11                     83.07   37     62491.01                230.87
# 12                     69.57   48     51636.92                113.12
# ...

# %%
df1 = df[df['Clicked on Ad'] == 1]
df1.plot(kind='hist', y='Daily Internet Usage')
df1.plot(kind='hist', y='Daily Time Spent on Site')
df1.plot(kind='hist', y='Age')


#df['Datetime'] = pd.to_datetime(df['Timestamp'])
#df['Datetime'] = df['Datetime'].dt.year
#df.set_index('Datetime')
#df.head()
#df.plot(kind='line', x='Datetime', y='Clicked on Ad')
# Out:
# <Axes: ylabel='Frequency'>
